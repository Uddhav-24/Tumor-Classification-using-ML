# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from google.colab import files
from sklearn import metrics

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-319313a6-924a-4826-afa3-dba5414d03e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-319313a6-924a-4826-afa3-dba5414d03e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-6-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# ...

# %%
mydf = pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7c3a8cc53397> in <module>()
# ----> 1 mydf = pd.read_csv("data.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
X = mydf.iloc[:,2:32].values
Y = mydf.iloc[:,1]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model = LogisticRegression(max_iter=3000)
model.fit(X_train,Y_train)
print("Successful")

# %%
Y_pred_test=model.predict(X_test)
Y_pred_train=model.predict(X_train)

# %%
print("Accuracy Testing=",metrics.accuracy_score(Y_test,Y_pred_test)*100,'%')
print("Accuracy Training=",metrics.accuracy_score(Y_train,Y_pred_train)*100,'%')
# Out:
# Accuracy Testing= 92.10526315789474 %
# Accuracy Training= 94.72527472527472 %

# %%
X_new = (7.76, 24.54, 47.92, 181, 0.05263, 0.04362, 0, 0, 0.1587, 0.05884, 0.3857, 1.428, 2.548, 19.15, 0.007189,
         0.00466, 0, 0, 0.02676, 0.002783, 9.456, 30.37, 59.16, 268.6, 0.08996, 0.06444, 0, 0, 0.2871, 0.07039)
input_data_as_numpy_array = np.asarray(X_new)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)
Y_new = model.predict(input_data_reshaped)
print(Y_new)
# Out:
# ['B']
